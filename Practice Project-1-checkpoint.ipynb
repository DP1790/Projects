# %% [markdown]
# # World Happiness Report

# %% [markdown]
# ## Data description

# %% [raw]
# The World Happiness Report is a landmark survey of the state of global happiness, which consists of ranks of 158 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity. The lowest scores observed for the six key variables, therefore, characterize Dystopia. The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.
# So based on this features i need to predict the happiness score, which is a target varaible & its a continuous feature.

# %%
## Importing libraries

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
## Read the CSV file and convert into dataframe

df = pd.read_csv('happiness_score_dataset.csv')
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.shape ## checking the data dimensions
# Out:
# (158, 12)

# %% [markdown]
# We have 158 rows & 12 columns including the target column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum() ## checking the null values
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.duplicated().sum() ## checking if there is any duplicate values
# Out:
# 0

# %%
## understanding the data at high level. checking the statistics of data set
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
## dropping the unwanted column

data = df.drop(columns=['Country','Region','Happiness Rank'])
data.head()
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# ...

# %% [markdown]
# Lets visualize the data & analyze the relationship between independent and dependent variables.

# %%
## lets see how data is distributed for every column

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.tight_layout()

# %%
data.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# The data distribution looks decent enough & there doesn't seem to be any skewness, only standard error has little skewness which can be considerable. So we can proceed !
#
# Let's observe the relationship between independent variable & dependent variable.

# %%
## Divide data set into features and label

y = data['Happiness Score']
x = data.drop(columns=['Happiness Score'])

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
# 5      7.406
# 6      7.378
# 7      7.364
# 8      7.286
# 9      7.284
# 10     7.278
# 11     7.226
# 12     7.200
# 13     7.187
# 14     7.119
# 15     6.983
# 16     6.946
# 17     6.940
# 18     6.937
# 19     6.901
# 20     6.867
# 21     6.853
# 22     6.810
# 23     6.798
# 24     6.786
# 25     6.750
# 26     6.670
# 27     6.611
# 28     6.575
# 29     6.574
# 30     6.505
# 31     6.485
# 32     6.477
# 33     6.455
# 34     6.411
# 35     6.329
# 36     6.302
# 37     6.298
# 38     6.295
# 39     6.269
# 40     6.168
# 41     6.130
# 42     6.123
# 43     6.003
# 44     5.995
# 45     5.987
# 46     5.984
# 47     5.975
# 48     5.960
# 49     5.948
# 50     5.890
# 51     5.889
# 52     5.878
# 53     5.855
# 54     5.848
# 55     5.833
# 56     5.828
# 57     5.824
# 58     5.813
# 59     5.791
# 60     5.770
# 61     5.759
# 62     5.754
# 63     5.716
# 64     5.709
# 65     5.695
# ...

# %%
x
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# 5           0.03140                   1.29025  1.31826
# 6           0.02799                   1.32944  1.28017
# 7           0.03157                   1.33171  1.28907
# 8           0.03371                   1.25018  1.31967
# 9           0.04083                   1.33358  1.30923
# 10          0.03470                   1.22857  1.22393
# 11          0.04454                   0.95578  1.23788
# 12          0.03751                   1.33723  1.29704
# 13          0.04176                   1.02054  0.91451
# 14          0.03839                   1.39451  1.24711
# 15          0.04076                   0.98124  1.23287
# ...

# %%
## Visualizing the relationship

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in x:
    if plotnumber<=8:
        ax = plt.subplot(4,4,plotnumber)
        sns.scatterplot(x[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Happiness Score', fontsize =20)
    
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# The relationship between independent variable & dependent variable look fairly linear except standard error. Hence we need to drop the feature.
# The data looks scaled. Hence we can go ahead with model building

# %%
## droping the standard eror column

x = data.drop(columns=['Standard Error','Happiness Score'])
y = data['Happiness Score']

# %%
x.head(2)
# Out:
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201

# %% [markdown]
# The data looks scaled. Hence we can go ahead and use linear regression & see how good it fits. but we need to split our data in train and test.

# %%
# Split the data into train and test. Model will be built on training data and tested on test data.
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=320)
y_train.head()
# Out:
# 138    3.989
# 18     6.937
# 98     4.876
# 64     5.709
# 65     5.695
# Name: Happiness Score, dtype: float64

# %% [markdown]
# ## Model initiating and training

# %%
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predict the Happiness Score

# %%
y_pred = regression.predict(x_test)
y_pred
# Out:
# array([5.58865715, 4.03311613, 6.85291332, 7.11948849, 3.89654606,
#        4.7148169 , 3.65595248, 7.36356475, 4.571475  , 6.29815549,
#        5.47372852, 3.65511548, 5.07328344, 4.19431684, 7.52695178,
#        6.81024818, 4.88451061, 6.29477387, 4.83923641, 5.12316181,
#        4.50728045, 3.99486003, 5.85523261, 6.66967019, 4.69397029,
#        5.39872721, 7.56084714, 4.6773714 , 4.30694874, 4.7864333 ,
#        5.77041447, 7.2256896 , 5.98375036, 6.48508805, 3.57461908,
#        4.51439521, 7.37805758, 4.86726985, 6.75009974, 5.28636592])

# %%
## adjusted R2 score
regression.score(x_train,y_train)
# Out:
# 0.9999999411160627

# %%
regression.score(x_test,y_test)
# Out:
# 0.9999999408701699

# %% [markdown]
# Lest plot and visualize

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Happiness Score')
plt.ylabel('predicted Happiness Score')
plt.title('Actual Vs Prediction')
plt.show()

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
y_pred = regression.predict(x_test)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.0002549970707842686

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 8.505862337124009e-08

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.00029164811566550553

# %% [markdown]
# Lets check with regularization if the model is overfitted or not

# %%
# LassoCV
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV

# %%
lasscv = LassoCV(alphas = None, max_iter= 1000, normalize=True)
lasscv.fit(x_train, y_train)
# Out:
# LassoCV(normalize=True)

# %%
# best alpha parameter
alpha = lasscv.alpha_
alpha
# Out:
# 8.085368821555791e-05

# %%
# now that we have the best parameter, lets use Lasso regression and see how well our data has fitted before

lasso_reg = Lasso(alpha)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=8.085368821555791e-05)

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.9999990324345782

# %%
## using RidgeCV

ridgecv = RidgeCV(alphas= np.arange(0.001,0.01,0.1), normalize=True)
ridgecv.fit(x_train, y_train)
# Out:
# RidgeCV(alphas=array([0.001]), normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.001

# %%
ridge_model = Ridge(alpha =ridgecv.alpha_)
ridge_model.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.001)

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.9999999184568819

# %% [markdown]
# Hence we could conclude that the linear regression model is fine & not overfitted.
